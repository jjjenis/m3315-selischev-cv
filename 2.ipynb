# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("LJwOUR0ZbzMGM_z5-toFtOoF9KOrnuVnlkQuF59wUvansYeYLgChGSuLuTFHFEKev57kVd3BIZV-F9StAMQ2l2dg.jpg")

# %%
img
# Out:
# array([[[253, 253, 253],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[248, 249, 245],
#         [250, 251, 247],
#         [253, 254, 250],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[245, 246, 242],
#         [248, 249, 245],
#         [251, 252, 248],
#         ...,
#         [254, 254, 254],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[243, 244, 240],
#         [246, 247, 243],
#         [250, 251, 247],
# ...

# %%
img_bgr = cv2.imread("LJwOUR0ZbzMGM_z5-toFtOoF9KOrnuVnlkQuF59wUvansYeYLgChGSuLuTFHFEKev57kVd3BIZV-F9StAMQ2l2dg.jpg")
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_rgb)
plt.title("RGB")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(183.5), np.float64(183.5), np.float64(-0.5))

# %%
plt.figure()
plt.imshow(img)
plt.title("Сырой BGR")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(183.5), np.float64(183.5), np.float64(-0.5))

# %%
img_gray = cv2.imread('/Users/denisandreevic/PycharmProjects/m3315-selischev-cv/LJwOUR0ZbzMGM_z5-toFtOoF9KOrnuVnlkQuF59wUvansYeYLgChGSuLuTFHFEKev57kVd3BIZV-F9StAMQ2l2dg.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
img_gray = cv2.imread('/Users/denisandreevic/PycharmProjects/m3315-selischev-cv/LJwOUR0ZbzMGM_z5-toFtOoF9KOrnuVnlkQuF59wUvansYeYLgChGSuLuTFHFEKev57kVd3BIZV-F9StAMQ2l2dg.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray,cmap='gray')

# %%
img_gray.shape
# Out:
# (184, 184)

# %%
img_rgb.shape
# Out:
# (184, 184, 3)

# %%
img =cv2.resize(img_rgb, (184, 1000))

# %%
plt.imshow(img)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
new_img =cv2.resize(img_rgb,(1,0),img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img = cv2.flip(new_img,-1)
plt.imshow(new_img)
